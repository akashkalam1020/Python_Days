# %% [markdown]
# ### 1. Why are functions advantageous to have in your programs?
# Solution ==>
#
#     Functions makes programs shorter, easier to read, and easier to update, as it is a reusable block of code means we haven't need to write same code again and again, we can define function once and use many times. Functions reduce the need for duplicate code.

# %% [markdown]
# ### 2. When does the code in a function run: when it's specified or when it's called?
# Solution ==>
#
#     The code in a function executes when the function is called, not when the function is defined. A function can return data as a result

# %% [markdown]
# ### 3. What statement creates a function?
# Solution ==>
#
#     To create a function we have to use a Keyword 'def' to define a function

# %%
# eg.,

def myfunction():
    
    # Code needs to be write here
    # It will return something
    
    return 'Done !!!'

myfunction()
# Out:
# 'Done !!!'

# %% [markdown]
# ### 4. What is the difference between a function and a function call?
# Solution ==>
#
#     A function is a block of code that does a particular operation and returns a result. It usually accepts inputs as parameters and returns a result.
#     Function call it process of calling the functionality of the defined funciton to do our task related to the perticular function by passing arguments to it.

# %% [markdown]
# ### 5. How many global scopes are there in a Python program? How many local scopes?
#
# Solution ==>
#
#     Global: The name defined in this scope are accessible to all our code.
#     Local: The name defined in this scope is accessible to only the block it was declared in. i.e. in its local block.
#
#     Types of Python Scope : -
#         There are four types of scope in Python: LEGB => Local - Enclosed - Global - BuiltIn, and the LEGB rule defines the order of scope.
#         when you try to read a variable, the python interpreter will retrieve the corresponding variable by looking up sequentially in the order of LEGB scopes, i.e. the first occurrence of this variable found in any of the scopes starting sequentially from, Local -> Enclosed -> Global -> BuiltIn, will be returned.

# %%
from PIL import Image
image = Image.open(r"C:\Users\akash\OneDrive\Pictures\Scope_fbrzcw.jpg")
# print(image.size)
new_img = image.resize((270, 266))
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=270x266 at 0x1FF3336CA08>

# %% [markdown]
#     1. Local Scope:
#         Local scope is determined by where the variable has been defined. For example: if the variable has been   defined inside a function, then its local scope would be defined as that function’s block only.

# %%
def func():
    b = "Local variable"
    print(b) # will print the string stored in variable b
    

func()
print(b) # nameError will be thrown as b exists only in func()'s local scope
# Out:
# Local variable
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2536/1596288101.py in <module>
#       5
#       6 func()
# ----> 7 print(b) # nameError will be thrown as b exists only in func()'s local scope
#
# NameError: name 'b' is not defined

# %% [markdown]
#     2. Enclosed Scope:
#         Also known as the non-local scope, can be observed when you nest functions inside other functions. Let’s say a function ‘func1()’ has a variable ‘a’ and a nested function ‘func2()’. For this nested function ‘func2()’, ‘a’ is neither global nor local. Hence, the scope of the variable ‘a’ inside ‘func2()’ is what the enclosed scope is, i.e. neither global nor local that’s why it’s also known as the non-local scope.

# %%
def fun1():
    a = 10
    
    def fun2():
        print(a)
    func2()
    
func1()
# Out:
# 10

# %% [markdown]
#     'nonlocal' Keyword:
#         The ‘nonlocal’ keyword is used to work in the scenarios where we have nested functions. Using the nonlocal keyword, we instruct the variable that it should not belong to the inner function.

# %%
def func1():
    a = 20
    def func2():
        nonlocal a
        a = 10
        print('func2 ', a)
    func2()
    print('func1 ', a)
func1()
# Out:
# func2  10
# func1  10

# %% [markdown]
#     3. Global Scope:
#         also known as module scope, when we start writing our code in python, we’re in the global scope. when we define a name at the top of our python module, then that name is global to that specific module only; that is why it’s also called the module scope

# %%
a = 'Global variable'

def func():
    a = 'Local variable'
    print(a) # shows output as Local variable
    

func()
print(a) # shows output as global variable
# Out:
# Local variable
# Global variable

# %% [markdown]
#     'global' Keyword:
#         ‘global’ keyword instructs variable that it does not belong to any function but exists globally.

# %%
a = 'Global variable'

def func():
    global a
    a = 'Local variable modified to global'    
    
print(a)
func()
print(a) # shows output as global variable
# Out:
# Global variable
# Local variable modified to global

# %% [markdown]
#     4. BuiltIn Scope:
#         When a python interpreter cannot find a variable in the Local, Enclosed and Global scope, it finally looks up in the builtIn scope. We are importing ‘pi’ from the math library in the following example. This imported ‘pi’ will belong  to the builtIn scope. Since, pi is not defined in either local, enclosed or global scope, the built-in scope is looked up i.e the pi value imported from math module. Since the program is able to find the value of pi in the outermost scope, the following output is obtained

# %%
from math import pi

def func1():
    print('inside func1 ', pi)

print('at global scope ', pi)
func1()
# Out:
# at global scope  3.141592653589793
# inside func1  3.141592653589793

# %% [markdown]
# ### 6. What happens to variables in a local scope when the function call returns?
# Solution ==>
#
#     It will return the value of the local variable.

# %%
def myfunc():
    x = 'Anything'
    print("variable is ",x)

myfunc()
# Out:
# variable is  Anything

# %% [markdown]
# ### 7. What is the concept of a return value? Is it possible to have a return value in an expression?
# Solution ==>
#
#     A return statement is used to end the execution of the function call and “returns” the result (value of the expression following the return keyword) to the caller. The statements after the return statements are not executed. If the return statement is without any expression, then the special value None is returned.

# %%
# eg.,

def myfunction():
    
    return 'Done !!!'

print(myfunction())
# Out:
# Done !!!

# %%
# eg.,

def myfunction():
    pass

print(myfunction())
# Out:
# None

# %% [markdown]
# ### 8. If a function does not have a return statement, what is the return value of a call to that function?
# Solution ==>
#
#     It alway return 'None' if there is no return statement.

# %% [markdown]
# ### 9. How do you make a function variable refer to the global variable?
# Solution ==>
#
#     we can use global Keyword to make local variable as global variable.

# %%
def myfunc():
    global x
    x = 100
    print("variable is:",x)

myfunc()
print(x)
# Out:
# variable is: 100
# 100

# %%
x = 100

def myfunc():
    x = 'Anything'
    print("variable is ",x)

myfunc()
print(x)
# Out:
# variable is  Anything
# 100

# %% [markdown]
# ### 10. What is the data type of None?
# Solution ==>
#
#     The data type of None is 'NoneType'.

# %% [markdown]
# ### 11. What does the sentence import areallyourpetsnamederic do?
# Solution ==>
#
#     That import statement imports a module named areallyourpetsnamederic.

# %% [markdown]
# ### 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %%
import spam # import spam as sm
spam.becon()  # sm.becon

# %% [markdown]
# ### 13. What can you do to save a programme from crashing if it encounters an error?
# Solution ==>
#
#     To handle such types of error we have a topic name as 'Exception handling', exceptions can be handled using a try statement. The critical operation which can raise an exception is placed inside the try clause. The code that handles the exceptions is written in the except clause. We can thus choose what operations to perform once we have caught the exception.

# %%
print(10 / 0) # It raises ZeroDivisionError but we have to excecute our programm without this error.
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16860/186921146.py in <module>
# ----> 1 print(10 / 0)
#
# ZeroDivisionError: division by zero

# %%
try:
    print(10 / 0)
except ZeroDivisionError:
    print("You are tring to divide a digit by zero\n")
finally : 
    print('Execution completed!!!')
# Out:
# You are tring to divide a digit by zero
#
# Execution completed!!!

# %% [markdown]
# ### 14. What is the purpose of the try clause? What is the purpose of the except clause?
# Solution ==>
#
#     The critical operation which can raise an exception is placed inside the try clause. The code that handles the exceptions is written in the except clause.
